# %%
import tkinter as tk
from tkinter import *
import tkinter.messagebox
from random import randint

count1L1=0
count2L1=0
count3L1=0
count4L1=0

count1L2=0
count2L2=0
count3L2=0
count4L2=0

count1L3=0
count2L3=0
count3L3=0
count4L3=0

count1L3=0
count2L3=0
count3L3=0
count4L3=0

count1L4=0
count2L4=0
count3L4=0
count4L4=0

count1L5=0
count2L5=0
count3L5=0
count4L5=0

count1L6=0
count2L6=0
count3L6=0
count4L6=0

count1L7=0
count2L7=0
count3L7=0
count4L7=0

count1L8=0
count2L8=0
count3L8=0
count4L8=0

combination = (randint(1,4),randint(1,4),randint(1,4),randint(1,4)) 
parameterV = 0
ligne = 0


def quitter():
    root.destroy()

def color(a):
    global count1L1
    global count2L1
    global count3L1
    global count4L1
    
    global count1L2
    global count2L2
    global count3L2
    global count4L2
    
    global count1L3
    global count2L3
    global count3L3
    global count4L3
    
    global count1L4
    global count2L4
    global count3L4
    global count4L4
    
    global count1L5
    global count2L5
    global count3L5
    global count4L5
    
    global count1L6
    global count2L6
    global count3L6
    global count4L6
    
    global count1L7
    global count2L7
    global count3L7
    global count4L7
    
    global count1L8
    global count2L8
    global count3L8
    global count4L8
    
    #LIGNE 1
    if a == 1:
        color = canvas1L1.itemcget(circle1L1, 'fill')
        if   color== 'red':
            canvas1L1.itemconfig(  circle1L1, fill='blue')
        elif color== 'blue':
            canvas1L1.itemconfig(  circle1L1, fill='green')
        elif color== 'green':
            canvas1L1.itemconfig(  circle1L1, fill='yellow')
        elif color== 'yellow':
            canvas1L1.itemconfig(  circle1L1, fill='red')
    elif a == 2:
        color = canvas2L1.itemcget(circle2L1, 'fill')
        if   color== 'red':
            canvas2L1.itemconfig(  circle2L1, fill='blue')
        elif color== 'blue':
            canvas2L1.itemconfig(  circle2L1, fill='green')
        elif color== 'green':
            canvas2L1.itemconfig(  circle2L1, fill='yellow')
        elif color== 'yellow':
            canvas2L1.itemconfig(  circle2L1, fill='red')
    elif a == 3:
        color = canvas3L1.itemcget(circle3L1, 'fill')
        if   color== "red":
            canvas3L1.itemconfig(  circle3L1, fill='blue')
        elif color== 'blue':
            canvas3L1.itemconfig(  circle3L1, fill='green')
        elif color== 'green':
            canvas3L1.itemconfig(  circle3L1, fill='yellow')
        elif color== 'yellow':
            canvas3L1.itemconfig(  circle3L1, fill='red')
    elif a == 4:
        color = canvas4L1.itemcget(circle4L1, 'fill')
        if   color== 'red':
            canvas4L1.itemconfig(  circle4L1, fill='blue')
        elif color== 'blue':
            canvas4L1.itemconfig(  circle4L1, fill='green')
        elif color== 'green':
            canvas4L1.itemconfig(  circle4L1, fill='yellow')
        elif color== 'yellow':
            canvas4L1.itemconfig(  circle4L1, fill='red')
    #LIGNE 2
    if a == 5:
        color = canvas1L2.itemcget(circle1L2, 'fill')
        if   color== 'red':
            canvas1L2.itemconfig(  circle1L2, fill='blue')
        elif color== 'blue':
            canvas1L2.itemconfig(  circle1L2, fill='green')
        elif color== 'green':
            canvas1L2.itemconfig(  circle1L2, fill='yellow')
        elif color== 'yellow':
            canvas1L2.itemconfig(  circle1L2, fill='red')
    elif a == 6:
        color = canvas2L2.itemcget(circle2L2, 'fill')
        if   color== 'red':
            canvas2L2.itemconfig(  circle2L2, fill='blue')
        elif color== 'blue':
            canvas2L2.itemconfig(  circle2L2, fill='green')
        elif color== 'green':
            canvas2L2.itemconfig(  circle2L2, fill='yellow')
        elif color== 'yellow':
            canvas2L2.itemconfig(  circle2L2, fill='red')
    elif a == 7:
        color = canvas3L2.itemcget(circle3L2, 'fill')
        if   color== "red":
            canvas3L2.itemconfig(  circle3L2, fill='blue')
        elif color== 'blue':
            canvas3L2.itemconfig(  circle3L2, fill='green')
        elif color== 'green':
            canvas3L2.itemconfig(  circle3L2, fill='yellow')
        elif color== 'yellow':
            canvas3L2.itemconfig(  circle3L2, fill='red')
    elif a == 8:
        color = canvas4L2.itemcget(circle4L2, 'fill')
        if   color== 'red':
            canvas4L2.itemconfig(  circle4L2, fill='blue')
        elif color== 'blue':
            canvas4L2.itemconfig(  circle4L2, fill='green')
        elif color== 'green':
            canvas4L2.itemconfig(  circle4L2, fill='yellow')
        elif color== 'yellow':
            canvas4L2.itemconfig(  circle4L2, fill='red')
    #LIGNE 3
    if a == 9:
        color = canvas1L3.itemcget(circle1L3, 'fill')
        if   color== 'red':
            canvas1L3.itemconfig(  circle1L3, fill='blue')
        elif color=='blue':
            canvas1L3.itemconfig(  circle1L3, fill='green')
        elif color=='green':
            canvas1L3.itemconfig(  circle1L3, fill='yellow')
        elif color=='yellow':
            canvas1L3.itemconfig(  circle1L3, fill='red')
    elif a == 10:
        color = canvas2L3.itemcget(circle2L3, 'fill')
        if   color== 'red':
            canvas2L3.itemconfig(  circle2L3, fill='blue')
        elif color=='blue':
            canvas2L3.itemconfig(  circle2L3, fill='green')
        elif color=='green':
            canvas2L3.itemconfig(  circle2L3, fill='yellow')
        elif color=='yellow':
            canvas2L3.itemconfig(  circle2L3, fill='red')
    elif a == 11:
        color = canvas3L3.itemcget(circle3L3, 'fill')
        if   color== "red":
            canvas3L3.itemconfig(  circle3L3, fill='blue')
        elif color=='blue':
            canvas3L3.itemconfig(  circle3L3, fill='green')
        elif color=='green':
            canvas3L3.itemconfig(  circle3L3, fill='yellow')
        elif color=='yellow':
            canvas3L3.itemconfig(  circle3L3, fill='red')
    elif a == 12:
        color = canvas4L3.itemcget(circle4L3, 'fill')
        if   color== 'red':
            canvas4L3.itemconfig(  circle4L3, fill='blue')
        elif color=='blue':
            canvas4L3.itemconfig(  circle4L3, fill='green')
        elif color=='green':
            canvas4L3.itemconfig(  circle4L3, fill='yellow')
        elif color=='yellow':
            canvas4L3.itemconfig(  circle4L3, fill='red')
    #LIGNE 4
    if a == 13:
        color = canvas1L4.itemcget(circle1L4, 'fill')
        if   color== 'red':
            canvas1L4.itemconfig(  circle1L4, fill='blue')
        elif color== 'blue':
            canvas1L4.itemconfig(  circle1L4, fill='green')
        elif color== 'green':
            canvas1L4.itemconfig(  circle1L4, fill='yellow')
        elif color== 'yellow':
            canvas1L4.itemconfig(  circle1L4, fill='red')
    elif a == 14:
        color = canvas2L4.itemcget(circle2L4, 'fill')
        if   color== 'red':
            canvas2L4.itemconfig(  circle2L4, fill='blue')
        elif color== 'blue':
            canvas2L4.itemconfig(  circle2L4, fill='green')
        elif color== 'green':
            canvas2L4.itemconfig(  circle2L4, fill='yellow')
        elif color== 'yellow':
            canvas2L4.itemconfig(  circle2L4, fill='red')
    elif a == 15:
        color = canvas3L4.itemcget(circle3L4, 'fill')
        if   color== "red":
            canvas3L4.itemconfig(  circle3L4, fill='blue')
        elif color== 'blue':
            canvas3L4.itemconfig(  circle3L4, fill='green')
        elif color== 'green':
            canvas3L4.itemconfig(  circle3L4, fill='yellow')
        elif color== 'yellow':
            canvas3L4.itemconfig(  circle3L4, fill='red')
    elif a == 16:
        color = canvas4L4.itemcget(circle4L4, 'fill')
        if   color== 'red':
            canvas4L4.itemconfig(  circle4L4, fill='blue')
        elif color== 'blue':
            canvas4L4.itemconfig(  circle4L4, fill='green')
        elif color== 'green':
            canvas4L4.itemconfig(  circle4L4, fill='yellow')
        elif color== 'yellow':
            canvas4L4.itemconfig(  circle4L4, fill='red')
    #LIGNE 5
    if a == 17:
        color = canvas1L5.itemcget(circle1L5, 'fill')
        if   color== 'red':
            canvas1L5.itemconfig(  circle1L5, fill='blue')
        elif color== 'blue':
            canvas1L5.itemconfig(  circle1L5, fill='green')
        elif color== 'green':
            canvas1L5.itemconfig(  circle1L5, fill='yellow')
        elif color== 'yellow':
            canvas1L5.itemconfig(  circle1L5, fill='red')
    elif a == 18:
        color = canvas2L5.itemcget(circle2L5, 'fill')
        if   color== 'red':
            canvas2L5.itemconfig(  circle2L5, fill='blue')
        elif color== 'blue':
            canvas2L5.itemconfig(  circle2L5, fill='green')
        elif color== 'green':
            canvas2L5.itemconfig(  circle2L5, fill='yellow')
        elif color== 'yellow':
            canvas2L5.itemconfig(  circle2L5, fill='red')
    elif a == 19:
        color = canvas3L5.itemcget(circle3L5, 'fill')
        if   color== "red":
            canvas3L5.itemconfig(  circle3L5, fill='blue')
        elif color== 'blue':
            canvas3L5.itemconfig(  circle3L5, fill='green')
        elif color== 'green':
            canvas3L5.itemconfig(  circle3L5, fill='yellow')
        elif color== 'yellow':
            canvas3L5.itemconfig(  circle3L5, fill='red')
    elif a == 20:
        color = canvas4L5.itemcget(circle4L5, 'fill')
        if   color== 'red':
            canvas4L5.itemconfig(  circle4L5, fill='blue')
        elif color== 'blue':
            canvas4L5.itemconfig(  circle4L5, fill='green')
        elif color== 'green':
            canvas4L5.itemconfig(  circle4L5, fill='yellow')
        elif color== 'yellow':
            canvas4L5.itemconfig(  circle4L5, fill='red')
    #LIGNE 6
    if a == 21:
        color = canvas1L6.itemcget(circle1L6, 'fill')
        if   color== 'red':
            canvas1L6.itemconfig(  circle1L6, fill='blue')
        elif color== 'blue':
            canvas1L6.itemconfig(  circle1L6, fill='green')
        elif color== 'green':
            canvas1L6.itemconfig(  circle1L6, fill='yellow')
        elif color== 'yellow':
            canvas1L6.itemconfig(  circle1L6, fill='red')
    elif a == 22:
        color = canvas2L6.itemcget(circle2L6, 'fill')
        if   color== 'red':
            canvas2L6.itemconfig(  circle2L6, fill='blue')
        elif color== 'blue':
            canvas2L6.itemconfig(  circle2L6, fill='green')
        elif color== 'green':
            canvas2L6.itemconfig(  circle2L6, fill='yellow')
        elif color== 'yellow':
            canvas2L6.itemconfig(  circle2L6, fill='red')
    elif a == 23:
        color = canvas3L6.itemcget(circle3L6, 'fill')
        if   color== "red":
            canvas3L6.itemconfig(  circle3L6, fill='blue')
        elif color== 'blue':
            canvas3L6.itemconfig(  circle3L6, fill='green')
        elif color== 'green':
            canvas3L6.itemconfig(  circle3L6, fill='yellow')
        elif color== 'yellow':
            canvas3L6.itemconfig(  circle3L6, fill='red')
    elif a == 24:
        color = canvas4L6.itemcget(circle4L6, 'fill')
        if   color== 'red':
            canvas4L6.itemconfig(  circle4L6, fill='blue')
        elif color== 'blue':
            canvas4L6.itemconfig(  circle4L6, fill='green')
        elif color== 'green':
            canvas4L6.itemconfig(  circle4L6, fill='yellow')
        elif color== 'yellow':
            canvas4L6.itemconfig(  circle4L6, fill='red')
    #LIGNE 7
    if a == 25:
        color = canvas1L7.itemcget(circle1L7, 'fill')
        if   color== 'red':
            canvas1L7.itemconfig(  circle1L7, fill='blue')
        elif color== 'blue':
            canvas1L7.itemconfig(  circle1L7, fill='green')
        elif color== 'green':
            canvas1L7.itemconfig(  circle1L7, fill='yellow')
        elif color== 'yellow':
            canvas1L7.itemconfig(  circle1L7, fill='red')
    elif a == 26:
        color = canvas2L7.itemcget(circle2L7, 'fill')
        if   color== 'red':
            canvas2L7.itemconfig(  circle2L7, fill='blue')
        elif color== 'blue':
            canvas2L7.itemconfig(  circle2L7, fill='green')
        elif color== 'green':
            canvas2L7.itemconfig(  circle2L7, fill='yellow')
        elif color== 'yellow':
            canvas2L7.itemconfig(  circle2L7, fill='red')
    elif a == 27:
        color = canvas3L7.itemcget(circle3L7, 'fill')
        if   color== "red":
            canvas3L7.itemconfig(  circle3L7, fill='blue')
        elif color== 'blue':
            canvas3L7.itemconfig(  circle3L7, fill='green')
        elif color== 'green':
            canvas3L7.itemconfig(  circle3L7, fill='yellow')
        elif color== 'yellow':
            canvas3L7.itemconfig(  circle3L7, fill='red')
    elif a == 28:
        color = canvas4L7.itemcget(circle4L7, 'fill')
        if   color== 'red':
            canvas4L7.itemconfig(  circle4L7, fill='blue')
        elif color== 'blue':
            canvas4L7.itemconfig(  circle4L7, fill='green')
        elif color== 'green':
            canvas4L7.itemconfig(  circle4L7, fill='yellow')
        elif color== 'yellow':
            canvas4L7.itemconfig(  circle4L7, fill='red')
    #LIGNE 8
    if a == 29:
        color = canvas1L8.itemcget(circle1L8, 'fill')
        if   color== 'red':
            canvas1L8.itemconfig(  circle1L8, fill='blue')
        elif color== 'blue':
            canvas1L8.itemconfig(  circle1L8, fill='green')
        elif color== 'green':
            canvas1L8.itemconfig(  circle1L8, fill='yellow')
        elif color== 'yellow':
            canvas1L8.itemconfig(  circle1L8, fill='red')
    elif a == 30:
        color = canvas2L8.itemcget(circle2L8, 'fill')
        if   color== 'red':
            canvas2L8.itemconfig(  circle2L8, fill='blue')
        elif color== 'blue':
            canvas2L8.itemconfig(  circle2L8, fill='green')
        elif color== 'green':
            canvas2L8.itemconfig(  circle2L8, fill='yellow')
        elif color== 'yellow':
            canvas2L8.itemconfig(  circle2L8, fill='red')
    elif a == 31:
        color = canvas3L8.itemcget(circle3L8, 'fill')
        if   color== "red":
            canvas3L8.itemconfig(  circle3L8, fill='blue')
        elif color== 'blue':
            canvas3L8.itemconfig(  circle3L8, fill='green')
        elif color== 'green':
            canvas3L8.itemconfig(  circle3L8, fill='yellow')
        elif color== 'yellow':
            canvas3L8.itemconfig(  circle3L8, fill='red')
    elif a == 32:
        color = canvas4L8.itemcget(circle4L8, 'fill')
        if   color== 'red':
            canvas4L8.itemconfig(  circle4L8, fill='blue')
        elif color== 'blue':
            canvas4L8.itemconfig(  circle4L8, fill='green')
        elif color== 'green':
            canvas4L8.itemconfig(  circle4L8, fill='yellow')
        elif color== 'yellow':
            canvas4L8.itemconfig(  circle4L8, fill='red')
    



#LIGNE 1
def clicked1(event):
    global count1L1
    global count1L2
    global count1L3
    global count1L4
    global count1L5
    global count1L6
    global count1L7
    global count1L8
    global ligne
    if ligne == 0:
        count1L1 += 1
    if ligne == 4:
        count1L2 += 1
    if ligne == 8:
        count1L3 += 1
    if ligne == 12:
        count1L4 += 1
    if ligne == 16:
        count1L5 += 1
    if ligne == 20:
        count1L6 += 1
    if ligne == 24:
        count1L7 += 1
    if ligne == 28:
        count1L8 += 1
    
def clicked2(event):
    global count2L1
    global count2L2
    global count2L3
    global count2L4
    global count2L5
    global count2L6
    global count2L7
    global count2L8
    global ligne
    if ligne == 0:
        count2L1 += 1
    if ligne == 4:
        count2L2 += 1
    if ligne == 8:
        count2L3 += 1
    if ligne == 12:
        count2L4 += 1
    if ligne == 16:
        count2L5 += 1
    if ligne == 20:
        count2L6 += 1
    if ligne == 24:
        count2L7 += 1
    if ligne == 28:
        count2L8 += 1
def clicked3(event):
    global count3L1
    global count3L2
    global count3L3
    global count3L4
    global count3L5
    global count3L6
    global count3L7
    global count3L8
    global ligne
    if ligne == 0:
        count3L1 += 1
    if ligne == 4:
        count3L2 += 1
    if ligne == 8:
        count3L3 += 1
    if ligne == 12:
        count3L4 += 1
    if ligne == 16:
        count3L5 += 1
    if ligne == 20:
        count3L6 += 1
    if ligne == 24:
        count3L7 += 1
    if ligne == 28:
        count3L8 += 1
def clicked4(event):
    global count4L1
    global count4L2
    global count4L3
    global count4L4
    global count4L5
    global count4L6
    global count4L7
    global count4L8
    global ligne
    if ligne == 0:
        count4L1 += 1
    if ligne == 4:
        count4L2 += 1
    if ligne == 8:
        count4L3 += 1
    if ligne == 12:
        count4L4 += 1
    if ligne == 16:
        count4L5 += 1
    if ligne == 20:
        count4L6 += 1
    if ligne == 24:
        count4L7 += 1
    if ligne == 28:
        count4L8 += 1




def validate(a):
    global parameterV
    global ligne
    if a == 0:
        ganswer = 0
        if count1L1%4+1 == combination[0]:
            ganswer+=1
        if count2L1%4+1 == combination[1]:
            ganswer+=1
        if count3L1%4+1 == combination[2]:
            ganswer+=1            
        if count4L1%4+1 == combination[3]:            
            ganswer+=1  

        lab_gaL1.config(text = "nombre de bonnes reponses : " + str(ganswer))
        
    if a == 1:
        ganswer = 0
        if count1L2%4+1 == combination[0]:            
            ganswer+=1            
        if count2L2%4+1 == combination[1]:            
            ganswer+=1            
        if count3L2%4+1 == combination[2]:            
            ganswer+=1       
        if count4L2%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL2.config(text = "nombre de bonnes reponses : " + str(ganswer))
    
    if a == 2:
        ganswer = 0
        if count1L3%4+1 == combination[0]:
            ganswer+=1
        if count2L3%4+1 == combination[1]:
            ganswer+=1
        if count3L3%4+1 == combination[2]:
            ganswer+=1
        if count4L3%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL3.config(text = "nombre de bonnes reponses : " + str(ganswer))

    if a == 3:
        ganswer = 0
        if count1L4%4+1 == combination[0]:
            ganswer+=1
        if count2L4%4+1 == combination[1]:
            ganswer+=1
        if count3L4%4+1 == combination[2]:
            ganswer+=1
        if count4L4%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL4.config(text = "nombre de bonnes reponses : " + str(ganswer))

    if a == 4:
        ganswer = 0
        if count1L5%4+1 == combination[0]:
            ganswer+=1
        if count2L5%4+1 == combination[1]:
            ganswer+=1
        if count3L5%4+1 == combination[2]:
            ganswer+=1
        if count4L5%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL5.config(text = "nombre de bonnes reponses : " + str(ganswer))

    if a == 5:
        ganswer = 0
        if count1L6%4+1 == combination[0]:
            ganswer+=1
        if count2L6%4+1 == combination[1]:
            ganswer+=1
        if count3L6%4+1 == combination[2]:
            ganswer+=1
        if count4L6%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL6.config(text = "nombre de bonnes reponses : " + str(ganswer))

    if a == 6:
        ganswer = 0
        if count1L7%4+1 == combination[0]:
            ganswer+=1
        if count2L7%4+1 == combination[1]:
            ganswer+=1
        if count3L7%4+1 == combination[2]:
            ganswer+=1
        if count4L7%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL7.config(text = "nombre de bonnes reponses : " + str(ganswer))

    if a == 7:
        ganswer = 0
        if count1L8%4+1 == combination[0]:
            ganswer+=1
        if count2L8%4+1 == combination[1]:
            ganswer+=1
        if count3L8%4+1 == combination[2]:
            ganswer+=1
        if count4L8%4+1 == combination[3]:
            ganswer+=1
            
        lab_gaL8.config(text = "nombre de bonnes reponses : " + str(ganswer))
    parameterV += 1
    ligne+=4
    if ganswer == 4:
        tkinter.messagebox.showinfo("CONGRATULATIONS","Well played, you won!")
        root.destroy()
    if ligne == 32:
        tkinter.messagebox.showinfo("YOU LOST","You'll do better next time")
        root.destroy()



root = tk.Tk()
root.title("MASTERMIND")


#les canevas:
#ligne 1
canvas1L1 = tk.Canvas(root, width=75, height= 75)
canvas1L1.grid(row=1, column= 1)
circle1L1 = canvas1L1.create_oval(5, 5, 70, 70, fill='red')

canvas2L1 = tk.Canvas(root, width=75, height= 75)
canvas2L1.grid(row=1, column= 2)
circle2L1 = canvas2L1.create_oval(5, 5, 70, 70, fill='red')

canvas3L1 = tk.Canvas(root, width=75, height= 75)
canvas3L1.grid(row=1, column= 3)
circle3L1 = canvas3L1.create_oval(5, 5, 70, 70, fill='red')

canvas4L1 = tk.Canvas(root, width=75, height= 75)
canvas4L1.grid(row=1, column= 4)
circle4L1 = canvas4L1.create_oval(5, 5, 70, 70, fill='red')


#ligne 2
canvas1L2 = tk.Canvas(root, width=75, height= 75)
canvas1L2.grid(row=2, column= 1)
circle1L2 = canvas1L2.create_oval(5, 5, 70, 70, fill='red')

canvas2L2 = tk.Canvas(root, width=75, height= 75)
canvas2L2.grid(row=2, column= 2)
circle2L2 = canvas2L2.create_oval(5, 5, 70, 70, fill='red')

canvas3L2 = tk.Canvas(root, width=75, height= 75)
canvas3L2.grid(row=2, column= 3)
circle3L2 = canvas3L2.create_oval(5, 5, 70, 70, fill='red')

canvas4L2 = tk.Canvas(root, width=75, height= 75)
canvas4L2.grid(row=2, column= 4)
circle4L2 = canvas4L2.create_oval(5, 5, 70, 70, fill='red')


#ligne 3
canvas1L3 = tk.Canvas(root, width=75, height= 75)
canvas1L3.grid(row=3, column= 1)
circle1L3 = canvas1L3.create_oval(5, 5, 70, 70, fill='red')

canvas2L3 = tk.Canvas(root, width=75, height= 75)
canvas2L3.grid(row=3, column= 2)
circle2L3 = canvas2L3.create_oval(5, 5, 70, 70, fill='red')

canvas3L3 = tk.Canvas(root, width=75, height= 75)
canvas3L3.grid(row=3, column= 3)
circle3L3 = canvas3L3.create_oval(5, 5, 70, 70, fill='red')

canvas4L3 = tk.Canvas(root, width=75, height= 75)
canvas4L3.grid(row=3, column= 4)
circle4L3 = canvas4L3.create_oval(5, 5, 70, 70, fill='red')


#ligne 4
canvas1L4 = tk.Canvas(root, width=75, height= 75)
canvas1L4.grid(row=4, column= 1)
circle1L4 = canvas1L4.create_oval(5, 5, 70, 70, fill='red')

canvas2L4 = tk.Canvas(root, width=75, height= 75)
canvas2L4.grid(row=4, column= 2)
circle2L4 = canvas2L4.create_oval(5, 5, 70, 70, fill='red')

canvas3L4 = tk.Canvas(root, width=75, height= 75)
canvas3L4.grid(row=4, column= 3)
circle3L4 = canvas3L4.create_oval(5, 5, 70, 70, fill='red')

canvas4L4 = tk.Canvas(root, width=75, height= 75)
canvas4L4.grid(row=4, column= 4)
circle4L4 = canvas4L4.create_oval(5, 5, 70, 70, fill='red')


#ligne 5
canvas1L5 = tk.Canvas(root, width=75, height= 75)
canvas1L5.grid(row=5, column= 1)
circle1L5 = canvas1L5.create_oval(5, 5, 70, 70, fill='red')

canvas2L5 = tk.Canvas(root, width=75, height= 75)
canvas2L5.grid(row=5, column= 2)
circle2L5 = canvas2L5.create_oval(5, 5, 70, 70, fill='red')

canvas3L5 = tk.Canvas(root, width=75, height= 75)
canvas3L5.grid(row=5, column= 3)
circle3L5 = canvas3L5.create_oval(5, 5, 70, 70, fill='red')

canvas4L5 = tk.Canvas(root, width=75, height= 75)
canvas4L5.grid(row=5, column= 4)
circle4L5 = canvas4L5.create_oval(5, 5, 70, 70, fill='red')


#ligne 6
canvas1L6 = tk.Canvas(root, width=75, height= 75)
canvas1L6.grid(row=6, column= 1)
circle1L6 = canvas1L6.create_oval(5, 5, 70, 70, fill='red')

canvas2L6 = tk.Canvas(root, width=75, height= 75)
canvas2L6.grid(row=6, column= 2)
circle2L6 = canvas2L6.create_oval(5, 5, 70, 70, fill='red')

canvas3L6 = tk.Canvas(root, width=75, height= 75)
canvas3L6.grid(row=6, column= 3)
circle3L6 = canvas3L6.create_oval(5, 5, 70, 70, fill='red')

canvas4L6 = tk.Canvas(root, width=75, height= 75)
canvas4L6.grid(row=6, column= 4)
circle4L6 = canvas4L6.create_oval(5, 5, 70, 70, fill='red')


#ligne 7
canvas1L7 = tk.Canvas(root, width=75, height= 75)
canvas1L7.grid(row=7, column= 1)
circle1L7 = canvas1L7.create_oval(5, 5, 70, 70, fill='red')

canvas2L7 = tk.Canvas(root, width=75, height= 75)
canvas2L7.grid(row=7, column= 2)
circle2L7 = canvas2L7.create_oval(5, 5, 70, 70, fill='red')

canvas3L7 = tk.Canvas(root, width=75, height= 75)
canvas3L7.grid(row=7, column= 3)
circle3L7 = canvas3L7.create_oval(5, 5, 70, 70, fill='red')

canvas4L7 = tk.Canvas(root, width=75, height= 75)
canvas4L7.grid(row=7, column= 4)
circle4L7 = canvas4L7.create_oval(5, 5, 70, 70, fill='red')


#ligne 8
canvas1L8 = tk.Canvas(root, width=75, height= 75)
canvas1L8.grid(row=8, column= 1)
circle1L8 = canvas1L8.create_oval(5, 5, 70, 70, fill='red')

canvas2L8 = tk.Canvas(root, width=75, height= 75)
canvas2L8.grid(row=8, column= 2)
circle2L8 = canvas2L8.create_oval(5, 5, 70, 70, fill='red')

canvas3L8 = tk.Canvas(root, width=75, height= 75)
canvas3L8.grid(row=8, column= 3)
circle3L8 = canvas3L8.create_oval(5, 5, 70, 70, fill='red')

canvas4L8 = tk.Canvas(root, width=75, height= 75)
canvas4L8.grid(row=8, column= 4)
circle4L8 = canvas4L8.create_oval(5, 5, 70, 70, fill='red')


buttonQ = tk.Button(root, width=10, height=5, command=quitter,text="Quitter")
buttonQ.grid(row = 0, column= 0)


buttonColor1 = tk.Button(root, width=10, height=5, text="",command=lambda : color(ligne + 1))
buttonColor1.grid(row = 9, column= 1)
buttonColor2 = tk.Button(root, width=10, height=5, text="",command=lambda : color(ligne + 2))
buttonColor2.grid(row = 9, column= 2)
buttonColor3 = tk.Button(root, width=10, height=5, text="",command=lambda : color(ligne + 3))
buttonColor3.grid(row = 9, column= 3)
buttonColor4 = tk.Button(root, width=10, height=5, text="",command=lambda : color(ligne + 4))
buttonColor4.grid(row = 9, column= 4)


buttonV = tk.Button(root, width=10, height=5, text="Valider",command=lambda : validate(parameterV))
buttonV.grid(row = 9, column= 5)


lab_gaL1=tk.Label(root,text="")
lab_gaL1.grid(column=0,row=1)

lab_gaL2=tk.Label(root,text="")
lab_gaL2.grid(column=0,row=2)

lab_gaL3=tk.Label(root,text="")
lab_gaL3.grid(column=0,row=3)

lab_gaL4=tk.Label(root,text="")
lab_gaL4.grid(column=0,row=4)

lab_gaL5=tk.Label(root,text="")
lab_gaL5.grid(column=0,row=5)

lab_gaL6=tk.Label(root,text="")
lab_gaL6.grid(column=0,row=6)

lab_gaL7=tk.Label(root,text="")
lab_gaL7.grid(column=0,row=7)

lab_gaL8=tk.Label(root,text="")
lab_gaL8.grid(column=0,row=8)

#LIGNE 1
buttonColor1.bind("<Button-1>",clicked1)
buttonColor2.bind("<Button-1>",clicked2)
buttonColor3.bind("<Button-1>",clicked3)
buttonColor4.bind("<Button-1>",clicked4)

root.mainloop()
